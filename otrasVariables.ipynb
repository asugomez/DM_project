# %% [markdown]
# ** Asunción Carolina Gómez Colomer **

# %%
import pandas as pd
# equipamiento cultural RM
df_equip_cult = pd.read_csv("./csv/new variables/Equipamiento_Cultural_RM.csv", sep=",")
df_equip_cult = df_equip_cult[["tipo", "direccion", "comuna"]]
df_equip_cult.head()
# Out:
#                          tipo                direccion       comuna
# 0  TEATRO Y SALA DE CONCIERTO            650 ESMERALDA     SANTIAGO
# 1  TEATRO Y SALA DE CONCIERTO                257 CUETO     SANTIAGO
# 2  TEATRO Y SALA DE CONCIERTO           1301 BALMACEDA     SANTIAGO
# 3  TEATRO Y SALA DE CONCIERTO    509 JOSE MIGUEL CLARO  PROVIDENCIA
# 4  TEATRO Y SALA DE CONCIERTO  1531 MARIO KREUTZBERGER     SANTIAGO

# %%
# establecimientos educacionales pre basicos
df_est_prebasicos = pd.read_csv("./csv/new variables/Establecimientos_educacionales_pre_basicos.csv", sep=",")
df_est_prebasicos = df_est_prebasicos[["tipo", "direccion", "comuna"]]
df_est_prebasicos.head()
# Out:
#         tipo             direccion    comuna
# 0  SALA CUNA      2185 WALDO SILVA  SANTIAGO
# 1  SALA CUNA  2722 GRAL RONDIZZONI  SANTIAGO
# 2  SALA CUNA      1650 JUAN VICUNA  SANTIAGO
# 3  SALA CUNA     584 CLEMENTE DIAZ      BUIN
# 4  SALA CUNA        461 NUEVO BUIN      BUIN

# %%
# ferias libres y persas
df_ferias = pd.read_csv("./csv/new variables/feriasLibresPersas.csv", sep=",")
df_ferias = df_ferias[["CALLE_0", "DESDE_0", "HASTA_0", "COMUNA"]]
df_ferias.tail()
# Out:
#                   CALLE_0           DESDE_0        HASTA_0        COMUNA
# 390             LOS MARES       LA ESTRELLA        OCEANIA      PUDAHUEL
# 391        LOS QUINCHEROS       EL ESFUERZO                 LO BARNECHEA
# 392         SAN FRANCISCO  JORGE WASHINGTON  TENIENTE CRUZ   CERRO NAVIA
# 393  MONS.ESCRIBA DE BALA      CLUB DE POLO                     VITACURA
# 394        MARIA ANGELICA  P QUEBRADA MACUL                   LA FLORIDA

# %%
df_parques_ind = pd.read_csv("./csv/new variables/Parques_Industriales_Santiago.csv", sep=",")

#df_ferias = df_ferias[["CALLE_0", "DESDE_0", "HASTA_0", "COMUNA"]]

df_parques_ind.tail()
# Out:
#     FID                               name                  layer  \
# 6     7  Barrio Industrial Puerto Santiago  Unknown Point Feature
# 7     8       barrio industrial puerta sur  Unknown Point Feature
# 8     9         Barrio industrial de Maipu  Unknown Point Feature
# 9    10         Barrio Industrial El Rosal  Unknown Point Feature
# 10   11                 Ciudad Empresarial  Unknown Point Feature
#
#                   gm_type
# 6   Unknown Point Feature
# 7   Unknown Point Feature
# 8   Unknown Point Feature
# 9   Unknown Point Feature
# 10  Unknown Point Feature

# %%
# Red seguridad RM
df_red_seg = pd.read_csv("./csv/new variables/Red_Seguridad_RM.csv", sep=",")
df_red_seg = df_red_seg[["tipo", "localid"]]
df_red_seg.head()
# Out:
#           tipo               localid
# 0  CARABINEROS         ISLA DE MAIPO
# 1  CARABINEROS              EL MONTE
# 2  CARABINEROS             TALAGANTE
# 3  CARABINEROS               POMAIRE
# 4  CARABINEROS  BAJOS DE SAN AGUSTIN

# %%
# Establecimientos educaciones publicos RM
df_est_ed_pub = pd.read_csv("./csv/new variables/Establecimientos_educaciones_pblicos_RM-k9d.csv", sep=",")
df_est_ed_pub = df_est_ed_pub[["tipo", "direccion", "coord_x", "coord_y", "localidad"]]
df_est_ed_pub.head()
# Out:
#            tipo             direccion       coord_x       coord_y localidad
# 0  ED PREBASICA  1900 ANTONIO MACHADO  347442.72845  6.285191e+06  SANTIAGO
# 1     ED BASICA   1949 VENANCIA LEIVA  347705.76039  6.285790e+06  SANTIAGO
# 2     ED BASICA        2769 EL OLIVAR  348779.19141  6.279349e+06  SANTIAGO
# 3      ED MEDIA         02669 EL OMBU  349217.67379  6.281664e+06  SANTIAGO
# 4     ED BASICA    02561 MIGUEL ANGEL  349130.79465  6.282411e+06  SANTIAGO

# %%
#Localizacion riesgos geofisicos
df_loc_riesgos_geo = pd.read_csv("./csv/new variables/Localizacin_riesgos_geofsicos.csv", sep=",", encoding='utf8') #encoding='latin1'
df_loc_riesgos_geo = df_loc_riesgos_geo[["upref", "comuna"]]
df_loc_riesgos_geo.tail()
# Out:
#                  upref             comuna
# 273  Riesgo Inundacion  Pudahuel - MaipÃº
# 274  Riesgo Inundacion          PeÃ±aflor
# 275  Riesgo Inundacion          CuracavÃ­
# 276  Riesgo Inundacion             Pirque
# 277  Riesgo Inundacion      Buin - Pirque

# %%
#Ciclovias RM
df_ciclovias= pd.read_csv("./csv/new variables/Red_de_ciclovas.csv", sep=",")
df_ciclovias = df_ciclovias[["FID", "name"]]
df_ciclovias.head(5)
# Out:
#    FID                                     name
# 0    1                      * IV Centenario (a)
# 1    2            * 5 de Abril / Esquina Blanca
# 2    3  * 5 de Abril / Parque por Simón Bolívar
# 3    4                    * Alameda / Pajaritos
# 4    5                          * Alberto Llona

# %%
#Clinicas RM
df_clinicas = pd.read_csv("./csv/new variables/Red_de_Clnicas.csv", sep=",")
df_clinicas = df_clinicas[["tipo", "direccion", "comuna"]]
df_clinicas.tail(5)
# Out:
#                tipo             direccion            comuna
# 27  CLINICA PRIVADA        5950 STA MARIA          VITACURA
# 28  CLINICA PRIVADA     5292 LUIS PASTEUR          VITACURA
# 29  CLINICA PRIVADA        6561LAGUNA SUR  ESTACION CENTRAL
# 30  CLINICA PRIVADA      3349 MAR TIRRENO         PENALOLEN
# 31  CLINICA PRIVADA  12351 CAMINO EL ALBA        LAS CONDES

# %%
# Establecimientos de salud (no tiene clinicas)
df_est_salud = pd.read_csv("./csv/new variables/Tipologa_de_Establecimientos_de_Salud.csv", sep=",")
# solo de la RM
df_est_salud = df_est_salud[ df_est_salud["nomreg"]=="Metropolitana de Santiago"]
df_est_salud = df_est_salud[["tipoest", "direcc", "latitud", "longitud"]]
df_est_salud.head(50)
# Out:
#                                                tipoest  \
# 274  Programa de Reparacion y Atencion Integral de ...
# 275                         Consultorio General Urbano
# 276                         Consultorio General Urbano
# 277                         Consultorio General Urbano
# 278                         Consultorio General Urbano
# 279                         Consultorio General Urbano
# 280                         Consultorio General Urbano
# 281                         Consultorio General Urbano
# 282                         Consultorio General Urbano
# 283                         Consultorio General Urbano
# 284                         Consultorio General Urbano
# 285                          Consultorio General Rural
# 286                         Consultorio General Urbano
# 287                         Consultorio General Urbano
# 288                         Consultorio General Urbano
# 289                         Consultorio General Urbano
# ...
